# %%
import pandas as pd
import numpy as np
import folium
import plotly.graph_objects as go

# %%
data_file_link = "time_series_covid19_confirmed_US_unpivot.csv"

# %%
url = ('time_series_covid19_confirmed_US_unpivot.csv')
data = pd.read_csv( url )

# %%
data.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key        Date  Death_Cases
# 0 -14.2710 -170.1320            American Samoa, US  2020-01-22            0
# 1  13.4443  144.7937                      Guam, US  2020-01-22            0
# 2  15.0979  145.6739  Northern Mariana Islands, US  2020-01-22            0
# 3  18.2208  -66.5901               Puerto Rico, US  2020-01-22            0
# 4  18.3358  -64.8963            Virgin Islands, US  2020-01-22            0

# %%
data.tail()
# Out:
#              UID iso2 iso3  code3  FIPS          Admin2 Province_State  \
# 538060  84070016   US  USA    840   NaN    Central Utah           Utah
# 538061  84070017   US  USA    840   NaN  Southeast Utah           Utah
# 538062  84070018   US  USA    840   NaN  Southwest Utah           Utah
# 538063  84070019   US  USA    840   NaN       TriCounty           Utah
# 538064  84070020   US  USA    840   NaN    Weber-Morgan           Utah
#
#        Country_Region        Lat       Long_              Combined_Key  \
# 538060             US  39.372319 -111.575868    Central Utah, Utah, US
# 538061             US  38.996171 -110.701396  Southeast Utah, Utah, US
# 538062             US  37.854472 -111.441876  Southwest Utah, Utah, US
# 538063             US  40.124915 -109.517442       TriCounty, Utah, US
# 538064             US  41.271160 -111.914512    Weber-Morgan, Utah, US
#
#               Date  Death_Cases
# 538060  2020-07-04          201
# 538061  2020-07-04           40
# ...

# %%
temp = data[data['Date']==max(data['Date'])]

m = folium.Map(location=[0, 0], titles='cartodbpositron', min_zoom = 1, max_zoom=4, zoom_start=1)
               
for i in range(0, len(temp)):
    folium.Circle(location=[temp.iloc[i]['Lat'], temp.iloc[i]['Long_']], color = 'crimson', fill = 'crimson', 
                 tooltip = '<li><bold> Province_State: ' + str(temp.iloc[i]['Province_State'])+
                             '<li><bold> Admin2: ' + str(temp.iloc[i]['Admin2'])+
                               '<li><bold> Death_Cases: ' + str(temp.iloc[i]['Death_Cases']),
radius = int(temp.iloc[i]['Death_Cases'])**0.5).add_to(m)
   
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = data['Date'], y = data['Cases'], mode = 'lines+markers', name = 'Cases', line = dict(color = 'Red', width = 4)))
fig.update_layout(title = 'Covid-19 Cases', xaxis_tickfont_size = 14, yaxis = dict(title = 'Number of Cases'))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cases'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7d5cee35009c> in <module>
#       1 fig = go.Figure()
# ...

# %%
data_us = data_us[data_us['Date'] >= '3/20/20']
data_us.copy().drop(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Combined_Key'],axis =1)

# %%
sns.relplot(x="Confirmed", y="Deaths", data=data)

# %%
sns.relplot(x="Deaths", y="state", data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Deaths', y='Confirmed', kind='line', data=data)

# %%
data.head()
