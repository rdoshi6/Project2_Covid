# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from splinter import Browser
import datefinder

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless = False)

# %%
nyt_url = 'https://www.nytimes.com/interactive/2020/us/states-reopen-map-coronavirus.html'

# %%
browser.visit(nyt_url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#Grabbing the states from the article.

dirty_states = soup.find_all('div', class_= 'g-name')
print(dirty_states[0])
# Out:
# <div class="g-name">Alaska</div>

# %%
#Stripping down to just the states.

states = []
for state in dirty_states:
    #print(state.contents[0])
    states.append(state.contents[0])

# %%
print(states[0:10])
# Out:
# ['Alaska', 'Iowa', 'Kansas', 'Kentucky', 'Minnesota', 'Missouri', 'Montana', 'Nebraska', 'New Hampshire', 'North Dakota']

# %%
#Grabbing the order types from the article.

dirty_orders = soup.find_all('div', class_= 'g-date-details')
print(dirty_orders[0])
# Out:
# <div class="g-date-details">
# <span>Stay-at-home order</span>
# <span class="g-date-details-text">expired on April 24.</span>
# </div>

# %%
order_type = []
for order in dirty_orders:
    order_type.append(order.contents[1].text)

# %%
#Cleaned Order Types
order_type[0:5]
# Out:
# ['Stay-at-home order',
#  'Did not have a statewide stay-at-home order.',
#  'Stay-at-home order',
#  'Healthy at home',
#  'Stay-at-home order']

# %%
#grabbing descriptions and dates of the orders
dirty_desc = soup.find_all('span', class_= 'g-date-details-text')
len(dirty_desc)
# Out:
# 52

# %%
kinda_dirty = []
for stuff in dirty_desc: 
    kinda_dirty.append(stuff.contents[0])

# %%
''''''
kinda_dirty[0]
# Out:
# 'expired on April 24.'

# %%
#status_list = ['expired', 'struck down', 'in effect', 'Did not have a statewide stay-at-home order.']

# %%
status = []

# %%
print('''important lists {order_type} {status} {states}
still need to make {dates}''')
# Out:
# important lists {order_type} {status} {states}
# still need to make {dates}

# %%
for dirt in kinda_dirty:
    if dirt[0:7] == 'expired':
        status.append(dirt[0:7])
    elif dirt[0:11] == 'struck down':
        status.append(dirt[0:11])
    elif dirt[0:9] == 'in effect':
        status.append(dirt[0:9])
    else: 
        status.append('N/A');

# %%
print(f'''States: {len(states)}
Order Types: {len(order_type)}
Statuses: {len(status)}''')
# Out:
# States: 52
# Order Types: 52
# Statuses: 52

# %%
#Now to collect the dates from the 'kinda_dirty' list
#kinda_dirty[28] is Puerto Rico, which has 2 dates listed. That gets sorted out later.
kinda_dirty[28]
# Out:
# 'expired on May 8.'

# %%
kinda_dirty.index('in effect since March 15 and set to expire July 22.')
# Out:
# 27

# %%
dates = []

# %%
for dirt in kinda_dirty:
    matches = datefinder.find_dates(dirt)
    for match in matches:
        dates.append(match)

# %%
#Sorting out the Puerto Rico dates problem
del dates[29]

# %%
#some states don't have dates to scrape, so i'm just looking for where these states are in my lists
indices = [i for i, x in enumerate(kinda_dirty) if x == "Did not have a statewide stay-at-home order."]

# %%
indices
# Out:
# [1, 7, 9, 10, 12, 13, 32, 44]

# %%
#placing date values as N/A for states with no stay-at-home orders
for i in indices:
    dates.insert(i, "N/A")

# %%
#"Did not have a statewide stay-at-home order." 
# ^ is REALLY wordy, so we're just replacing those with a order type of "None"
# and removing redundancy of the word "order" after "stay-at-home" 
for i, x in enumerate(order_type):
    if x == "Did not have a statewide stay-at-home order.":
        order_type[i] = "None"
    elif x == "Stay-at-home order":
        order_type[i] = "Stay-at-home"

# %%
print(f'''State       Order Type
{states[32]}        {order_type[32]}
{states[40]}        {order_type[40]}''')
# Out:
# State       Order Type
# Arkansas        None
# North Carolina        Stay-at-home

# %%
print(f'''Dates:{len(dates)}
States:{len(states)}
Orders:{len(order_type)}
Statusi:{len(status)}''')
# Out:
# Dates:52
# States:52
# Orders:52
# Statusi:52

# %%
#Now we're good to put everything into into a dataframe

# %%
df = pd.DataFrame(list(zip(states, order_type, dates, status)), 
               columns =['State', 'Order_type', 'Date', 'Status'])
df.head()
# Out:
#        State       Order_type                 Date     Status
# 0     Alaska     Stay-at-home  2020-04-24 00:00:00    expired
# 1       Iowa             None                  N/A        N/A
# 2     Kansas     Stay-at-home  2020-05-03 00:00:00    expired
# 3   Kentucky  Healthy at home  2020-03-26 00:00:00  in effect
# 4  Minnesota     Stay-at-home  2020-05-17 00:00:00    expired

# %%
#df.to_csv('CSVs/Quarantine_Dates_By_State.csv', encoding='utf-8', index=False)

# %%
df.sort_values('State', ascending=True, inplace=True)

# %%
df
# Out:
#                    State             Order_type                 Date  \
# 31               Alabama           Stay-at-home  2020-05-15 00:00:00
# 0                 Alaska           Stay-at-home  2020-04-24 00:00:00
# 45               Arizona           Stay-at-home  2020-05-15 00:00:00
# 32              Arkansas                   None                  N/A
# 46            California           Stay-at-home  2020-03-19 00:00:00
# 47              Colorado           Stay-at-home  2020-04-26 00:00:00
# 33           Connecticut           Stay-at-home  2020-04-30 00:00:00
# 34              Delaware       Shelter in place  2020-05-20 00:00:00
# 17  District of Columbia           Stay-at-home  2020-05-29 00:00:00
# 48               Florida           Stay-at-home  2020-05-04 00:00:00
# 18               Georgia       Shelter in place  2020-04-30 00:00:00
# 19                Hawaii           Stay-at-home  2020-05-31 00:00:00
# 35                 Idaho           Stay-at-home  2020-05-31 00:00:00
# 20              Illinois           Stay-at-home  2020-05-29 00:00:00
# 36               Indiana           Stay-at-home  2020-05-04 00:00:00
# 1                   Iowa                   None                  N/A
# 2                 Kansas           Stay-at-home  2020-05-03 00:00:00
# 3               Kentucky        Healthy at home  2020-03-26 00:00:00
# 37             Louisiana           Stay-at-home  2020-05-15 00:00:00
# 21                 Maine           Stay-at-home  2020-05-31 00:00:00
# 22              Maryland           Stay-at-home  2020-05-15 00:00:00
# 23         Massachusetts  Stay-at-home advisory  2020-05-18 00:00:00
# 49              Michigan           Stay-at-home  2020-06-01 00:00:00
# 4              Minnesota           Stay-at-home  2020-05-17 00:00:00
# 38           Mississippi       Shelter in place  2020-04-27 00:00:00
# 5               Missouri           Stay-at-home  2020-05-03 00:00:00
# 6                Montana           Stay-at-home  2020-04-26 00:00:00
# 7               Nebraska                   None                  N/A
# 39                Nevada           Stay-at-home  2020-05-09 00:00:00
# 8          New Hampshire           Stay-at-home  2020-06-15 00:00:00
# 24            New Jersey           Stay-at-home  2020-06-09 00:00:00
# 50            New Mexico           Stay-at-home  2020-05-31 00:00:00
# 25              New York           Stay-at-home  2020-05-28 00:00:00
# 40        North Carolina           Stay-at-home  2020-05-22 00:00:00
# 9           North Dakota                   None                  N/A
# 26                  Ohio           Stay-at-home  2020-05-29 00:00:00
# 10              Oklahoma                   None                  N/A
# 41                Oregon           Stay-at-home  2020-03-23 00:00:00
# 11          Pennsylvania           Stay-at-home  2020-06-04 00:00:00
# 27           Puerto Rico                 Curfew  2020-03-15 00:00:00
# 28          Rhode Island           Stay-at-home  2020-07-22 00:00:00
# 42        South Carolina           Stay-at-home  2020-05-04 00:00:00
# 12          South Dakota                   None                  N/A
# 29             Tennessee           Stay-at-home  2020-05-08 00:00:00
# 51                 Texas           Stay-at-home  2020-04-30 00:00:00
# 13                  Utah                   None                  N/A
# 30               Vermont           Stay-at-home  2020-04-30 00:00:00
# 14              Virginia           Stay-at-home  2020-06-10 00:00:00
# 43            Washington           Stay-at-home  2020-05-31 00:00:00
# 15         West Virginia           Stay-at-home  2020-05-03 00:00:00
# 16             Wisconsin           Stay-at-home  2020-05-13 00:00:00
# 44               Wyoming                   None                  N/A
#
#          Status
# 31      expired
# 0       expired
# 45      expired
# 32          N/A
# 46    in effect
# 47      expired
# 33      expired
# 34      expired
# 17      expired
# 48      expired
# 18      expired
# 19      expired
# 35      expired
# 20      expired
# 36      expired
# 1           N/A
# 2       expired
# 3     in effect
# 37      expired
# 21      expired
# 22      expired
# 23      expired
# 49      expired
# 4       expired
# 38      expired
# 5       expired
# 6       expired
# 7           N/A
# 39      expired
# 8       expired
# 24      expired
# 50      expired
# 25      expired
# 40      expired
# 9           N/A
# 26      expired
# 10          N/A
# 41    in effect
# 11      expired
# 27    in effect
# 28      expired
# 42      expired
# 12          N/A
# 29      expired
# 51      expired
# 13          N/A
# 30      expired
# 14      expired
# 43      expired
# 15      expired
# 16  struck down
# 44          N/A

# %%
df.set_index('State', inplace=True)

# %%
df
# Out:
#                                  Order_type                 Date       Status
# State
# Alabama                        Stay-at-home  2020-05-15 00:00:00      expired
# Alaska                         Stay-at-home  2020-04-24 00:00:00      expired
# Arizona                        Stay-at-home  2020-05-15 00:00:00      expired
# Arkansas                               None                  N/A          N/A
# California                     Stay-at-home  2020-03-19 00:00:00    in effect
# Colorado                       Stay-at-home  2020-04-26 00:00:00      expired
# Connecticut                    Stay-at-home  2020-04-30 00:00:00      expired
